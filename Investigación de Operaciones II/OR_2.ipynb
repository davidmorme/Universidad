# %% [markdown]
# <a href="https://colab.research.google.com/github/davidmorme/Universidad/blob/main/Investigaci%C3%B3n%20de%20Operaciones%20II/OR_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Edición vacía

# %%
import pandas as pd
import numpy as np
import plotly.figure_factory as ff
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt 
fig, gnt = plt.subplots() 
gnt.set_ylim(0, 25) 
gnt.set_xlim(0, 50) 
gnt.set_xlabel('X-Axis') 
gnt.set_ylabel('Y-Axis') 
gnt.set_yticks([10, 15, 20]) 
gnt.set_yticklabels(['10', '15', '20']) 
gnt.grid(True) 
gnt.broken_barh([(15, 10)], (10, 5), facecolors='green') 
gnt.broken_barh([(35, 10)], (1, 5), facecolors =('tab:pink'))

# %%
Inicios=pd.read_excel('Libro1.xlsx',sheet_name='Hoja1',index_col=0)
Duraciones=pd.read_excel('Libro1.xlsx',sheet_name='Hoja2',index_col=0)
Colores=pd.read_excel('Libro1.xlsx',sheet_name='Hoja3')

# %%
Colors=list(Colores['Colors'])

# %%
Colors+=Colors

# %%
len(Colors)
# Out:
# 224

# %%
Inicios.columns=[50,40,30,20,10,0]
Duraciones.columns=[50,40,30,20,10,0]

# %%
Duraciones.columns
# Out:
# Int64Index([50, 40, 30, 20, 10, 0], dtype='int64')

# %%
ancho=7
plt.rcParams['figure.figsize'] = (16, 9)
fig, gnt = plt.subplots() 
gnt.set_title('Diagrama de Gantt de Solución Python con Nuevo recurso') 
gnt.set_ylim(0, 60) 
gnt.set_xlim(0, 6050) 
gnt.set_yticks([5,15,25,35,45,55])
gnt.set_yticklabels(['P5','P4','P3-2','P3-1','P2','P1'])
gnt.grid(False) 
for j in Inicios.columns:
  for i in range(0,len(Inicios[j])):
    gnt.broken_barh([(Inicios[j].iloc[i], Duraciones[j].iloc[i])], (j, ancho), facecolors=Colors[i]) 
fig.savefig('Gantt Python Nuevo Recurso.png',transparent=True)

# %%
Inicios=pd.read_excel('Libro2.xlsx',sheet_name='Hoja1',index_col=0)
Duraciones=pd.read_excel('Libro2.xlsx',sheet_name='Hoja2',index_col=0)

# %%
Inicios.columns=[40,30,20,10,0]
Duraciones.columns=[40,30,20,10,0]

# %%
ancho=7
plt.rcParams['figure.figsize'] = (16, 9)
fig, gnt = plt.subplots() 
gnt.set_title('Diagrama de Gantt de Solución Gams') 
gnt.set_ylim(0, 50) 
gnt.set_xlim(0, 6150) 
gnt.set_yticks([5,15,25,35,45])
gnt.set_yticklabels(['P5','P4','P3','P2','P1'])
gnt.grid(False) 
for j in Inicios.columns:
  for i in range(0,len(Inicios[j])):
    gnt.broken_barh([(Inicios[j].iloc[i], Duraciones[j].iloc[i])], (j, ancho), facecolors=Colors[i]) 
fig.savefig('Gantt Gams.png',transparent=True)

# %%
Inicio=[15,35]
Duracion=[10,10]
ancho=5
Maquina=[10,20]
import matplotlib.pyplot as plt 
fig, gnt = plt.subplots() 
gnt.set_ylim(0, 25) 
gnt.set_xlim(0, 50) 
gnt.set_xlabel('X-Axis') 
gnt.set_ylabel('Y-Axis') 
gnt.set_yticks([10, 15, 20]) 
gnt.set_yticklabels(['10', '15', '20']) 
gnt.grid(True) 
for i in range(0,len(Inicio)):
  gnt.broken_barh([(Inicio[i], Duracion[i])], (Maquina[i], ancho), facecolors='#FF00FF')

# %%
df=[dict(Task='Job A', Start= '2009-01-01',Finish='2009-02-28'),
    dict(Task='Job B', Start= '2009-03-05',Finish='2009-04-15'),
    dict(Task='Job C', Start= '2009-01-01',Finish='2009-02-28')]
fig = ff.create_gantt(df)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e361d00f-9391-48ce-8e89-d68d83c999be" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e361d00f-9391-48ce-8e89-d68d83c999be")) {
#                     Plotly.newPlot(
#                         'e361d00f-9391-48ce-8e89-d68d83c999be',
# ...

# %%
import plotly.figure_factory as ff

df=[dict(Task='Creación de Forms', Start= '2021-08-23',Finish='2021-09-10'),
    dict(Task='Creación Flujo Power Automate', Start= '2021-09-13',Finish='2021-09-22'),
    dict(Task='Elaboración informe de avance', Start= '2021-09-23',Finish='2021-09-30'),
    dict(Task='Elaboración Power Bi', Start= '2021-10-11',Finish='2021-10-23'),
    dict(Task='Crear exportación a pdf', Start= '2021-09-13',Finish='2021-10-23'),
    dict(Task='Evaluación de impacto*', Start= '2021-10-23',Finish='2021-11-09'),
    dict(Task='Elaboración de vídeo', Start= '2021-10-23',Finish='2021-10-31'),
    dict(Task='Elaboración informe de avance', Start= '2021-10-23',Finish='2021-11-09')]
fig = ff.create_gantt(df,title='Plan de trabajo Micropráctica David Mora')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f7a0d83b-0c29-438a-acbc-0bb59cd1d9d5" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f7a0d83b-0c29-438a-acbc-0bb59cd1d9d5")) {
#                     Plotly.newPlot(
#                         'f7a0d83b-0c29-438a-acbc-0bb59cd1d9d5',
# ...

# %%
import plotly.figure_factory as ff

df=[dict(Task='Creación de Forms', Start= '2021-08-23',Finish='2021-09-10'),
    dict(Task='Creación Flujo Power Automate', Start= '2021-09-13',Finish='2021-09-22'),
    dict(Task='Elaboración informe de avance', Start= '2021-09-23',Finish='2021-09-30'),
    dict(Task='Elaboración Power Bi', Start= '2021-10-11',Finish='2021-10-23'),
    dict(Task='Crear exportación a pdf', Start= '2021-09-13',Finish='2021-10-23'),
    dict(Task='Evaluación de impacto*', Start= '2021-10-23',Finish='2021-11-09'),
    dict(Task='Elaboración de vídeo', Start= '2021-10-23',Finish='2021-10-31'),
    dict(Task='Elaboración informe de avance', Start= '2021-10-23',Finish='2021-11-09')]
fig = ff.create_gantt(df,title='Plan de trabajo Micropráctica Con Retrasos David Mora',colors=['#45c819', '#ffff00', '#45c819','rgb(200, 50, 25)','rgb(200, 50, 25)','rgb(200, 50, 25)','rgb(200, 50, 25)','rgb(200, 50, 25)'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6cae668d-43a0-4d4d-8b7e-3e5022936ef7" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6cae668d-43a0-4d4d-8b7e-3e5022936ef7")) {
#                     Plotly.newPlot(
#                         '6cae668d-43a0-4d4d-8b7e-3e5022936ef7',
# ...

# %%
import plotly.figure_factory as ff

df=[dict(Task='Creación de Forms', Start= '2021-09-06',Finish='2021-09-23'),
    dict(Task='Creación Flujo Power Automate', Start= '2021-09-23',Finish='2021-10-08'),
    dict(Task='Elaboración informe de avance', Start= '2021-09-28',Finish='2021-10-01'),
    dict(Task='Presentación y corrección de Forms', Start= '2021-10-01',Finish='2021-10-08'),
    dict(Task='Elaboración Power Bi', Start= '2021-10-11',Finish='2021-10-23'),
    dict(Task='Crear exportación a pdf', Start= '2021-10-12',Finish='2021-10-23'),
    dict(Task='Evaluación de impacto*', Start= '2021-10-23',Finish='2021-11-09'),
    dict(Task='Elaboración de vídeo', Start= '2021-10-23',Finish='2021-10-31'),
    dict(Task='Elaboración informe de avance', Start= '2021-10-31',Finish='2021-11-09')]
fig = ff.create_gantt(df,title='Plan de trabajo Micropráctica Actualizado David Mora',colors=['#45c819', '#ffff00', '#45c819','rgb(200, 50, 25)','rgb(200, 50, 25)','rgb(200, 50, 25)','rgb(200, 50, 25)','rgb(200, 50, 25)','rgb(200, 50, 25)'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8b23eb51-7738-4957-b604-717c452e5c8a" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8b23eb51-7738-4957-b604-717c452e5c8a")) {
#                     Plotly.newPlot(
#                         '8b23eb51-7738-4957-b604-717c452e5c8a',
# ...

# %%
df1 = [dict(Task="Job A", Start='2009-01-01',
           Finish='2009-02-28', Resource='Apple'),
      dict(Task="Job B", Start='2009-03-05',
           Finish='2009-04-15', Resource='Grape'),
      dict(Task="Job C", Start='2009-02-20',
           Finish='2009-05-30', Resource='Banana')]
fig = ff.create_gantt(df1, colors=['rgb(200, 50, 25)', (1, 0, 1), '#6c4774'],
                   index_col='Resource', reverse_colors=True,
                   show_colorbar=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2762b678-736e-4ea5-b9cd-786abbd5105a" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2762b678-736e-4ea5-b9cd-786abbd5105a")) {
#                     Plotly.newPlot(
#                         '2762b678-736e-4ea5-b9cd-786abbd5105a',
# ...

# %%
# !pip install criticalpath
# Out:
# ...
#   Created wheel for criticalpath: filename=criticalpath-0.1.5-cp37-none-any.whl size=12041 sha256=5f7aecb740473c985f9405df75ca975bc3618ffc96d2ba0453b26c095d222ef2
#   Stored in directory: /root/.cache/pip/wheels/49/07/a6/e04086e98dc47934106a674b7fe4708ef4f49168f39266a182
# Successfully built criticalpath
# ...

# %%
from criticalpath import Node
p=Node('project')
a=p.add(Node('A',duration=3))
b=p.add(Node('B',duration=3, lag=0))
c=p.add(Node('C',duration=4, lag=0))
d=p.add(Node('D',duration=6, lag=0))
e=p.add(Node('E',duration=5, lag=0))
p.link(a,b).link(a,c).link(a,d).link(b,e).link(c,e).link(d,e)
p.update_all()
p.get_critical_path()
# Out:
# [A, D, E]

# %%
p.duration
# Out:
# 14

# %%
#pd.read_csv()
BaseDatos = pd.read_csv('/5000-Sales-Records.csv', sep=",")
BaseDatos
# Out:
#                                  Region  ... Total Profit
# 0     Central America and the Caribbean  ...     52914.72
# 1     Central America and the Caribbean  ...    119488.38
# 2                                Europe  ...     74823.48
# 3                                  Asia  ...    798727.44
# 4                                  Asia  ...    415865.88
# ...                                 ...  ...          ...
# 4995              Australia and Oceania  ...    879197.65
# 4996       Middle East and North Africa  ...     79094.88
# 4997                               Asia  ...    498855.44
# 4998                             Europe  ...    691070.40
# 4999                 Sub-Saharan Africa  ...    154668.50
#
# [5000 rows x 14 columns]

# %%
BaseDatos.describe()
# Out:
#            Order ID   Units Sold  ...    Total Cost  Total Profit
# count  5.000000e+03  5000.000000  ...  5.000000e+03  5.000000e+03
# mean   5.486447e+08  5030.698200  ...  9.330932e+05  3.926446e+05
# std    2.594671e+08  2914.515427  ...  1.150873e+06  3.829351e+05
# min    1.000909e+08     2.000000  ...  4.844000e+01  1.687000e+01
# 25%    3.201042e+08  2453.000000  ...  1.547480e+05  8.533925e+04
# 50%    5.523150e+08  5123.000000  ...  4.681807e+05  2.790952e+05
# 75%    7.687709e+08  7576.250000  ...  1.189578e+06  5.651064e+05
# max    9.998797e+08  9999.000000  ...  5.248025e+06  1.726007e+06
#
# [8 rows x 7 columns]

# %%
BaseDatos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          5000 non-null   object
#  1   Country         5000 non-null   object
#  2   Item Type       5000 non-null   object
#  3   Sales Channel   5000 non-null   object
#  4   Order Priority  5000 non-null   object
#  5   Order Date      5000 non-null   object
#  6   Order ID        5000 non-null   int64
#  7   Ship Date       5000 non-null   object
#  8   Units Sold      5000 non-null   int64
#  9   Unit Price      5000 non-null   float64
#  10  Unit Cost       5000 non-null   float64
#  11  Total Revenue   5000 non-null   float64
#  12  Total Cost      5000 non-null   float64
#  13  Total Profit    5000 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 547.0+ KB

# %%
BaseDatos.boxplot(column=['Total Profit','Total Cost','Total Revenue'])

# %%
plt.hist(BaseDatos['Item Type'])
plt.xticks(rotation=45)
plt.show()

# %%
data_filter_task = BaseDatos[['Region', 'Country', 'Item Type', 'Sales Channel']]
data_filter_task = data_filter_task[data_filter_task['Sales Channel']== 'Online']
data_filter_task[0:10]
# Out:
#                                Region  ... Sales Channel
# 0   Central America and the Caribbean  ...        Online
# 7                              Europe  ...        Online
# 9                  Sub-Saharan Africa  ...        Online
# 11       Middle East and North Africa  ...        Online
# 14  Central America and the Caribbean  ...        Online
# 17                             Europe  ...        Online
# 18                      North America  ...        Online
# 22                             Europe  ...        Online
# 25  Central America and the Caribbean  ...        Online
# 27  Central America and the Caribbean  ...        Online
#
# [10 rows x 4 columns]

# %%
Total_cost=BaseDatos[['Total Cost']]
Total_cost[0:5]
# Out:
#    Total Cost
# 0    87999.84
# 1   211152.48
# 2   151892.62
# 3  1055863.76
# 4   734892.48

# %%
Total_cost.to_csv('out.csv')

# %%
import seaborn as sns
sns.distplot(Total_cost)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
sns.histplot(Total_cost)
plt.show()

# %%
Total_cost[0:1]
# Out:
#    Total Cost
# 0    87999.84

# %%
plt.hist(BaseDatos['Total Cost'],density=True)
plt.show()
plt.hist(BaseDatos['Total Cost'],density=False)
plt.show()

# %%
plt.hist(Total_cost)
plt.show()

# %%
sns.displot(Total_cost)
plt.show()

# %%
plt.hist(BaseDatos['Total Cost'],density=True, bins=50,cumulative=False,)
sns.kdeplot(BaseDatos['Total Cost'],cumulative=False)
plt.show()
plt.hist(BaseDatos['Total Cost'],density=True, bins=50,cumulative=True)
sns.kdeplot(BaseDatos['Total Cost'],cumulative=True)
plt.show()

# %%
# Task: Get 50 lines from "Unit Cost" and "Total Profit" and save it to the file unit_cost.csv 
BaseDatos[['Unit Cost','Total Profit']][0:50].to_csv('unit_cost.csv')

# %%
df = pd.DataFrame (BaseDatos, columns = ['Total Cost','Units Sold','Total Profit'])
sns.pairplot(df) #corner=True

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from scipy.stats import norm

mu, sigma = 100, 15
x = mu + sigma*np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, facecolor='green', alpha=0.75,density=1)

# add a 'best fit' line
y = norm.pdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title(r'$\mathrm{Histogram\ of\ IQ:}\ \mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)

plt.show()

# %%
my_colors=list('rgbkymc')
BaseDatos['Item Type'].value_counts().plot(kind='bar', color = my_colors)
plt.show()
BaseDatos['Item Type'].value_counts().plot(kind='barh', color = my_colors)
plt.show()

# %%
BaseDatos['Item Type'].value_counts().plot(kind='pie')
plt.show()

# %%
from scipy.stats import kurtosis, skew
print( 'excess kurtosis of normal distribution (should be 0): {}'.format( kurtosis( BaseDatos['Unit Cost']) ))

print( 'skewness of normal distribution (should be 0): {}'.format( BaseDatos['Unit Cost'] ))
# Out:
# excess kurtosis of normal distribution (should be 0): -0.6933780415112145
# skewness of normal distribution (should be 0): 0       159.42
# 1        97.44
# 2        31.79
# 3       117.11
# 4        97.44
#          ...
# 4995    502.54
# 4996     35.84
# 4997    159.42
# 4998     35.84
# 4999     90.93
# Name: Unit Cost, Length: 5000, dtype: float64

# %%
sns.distplot(BaseDatos['Unit Cost'], hist=True, kde=True, 

             bins=int(180/5), color = 'darkblue', 

             hist_kws={'edgecolor':'black'},

             kde_kws={'linewidth': 4})
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
np.median(BaseDatos['Unit Cost'])
# Out:
# 97.44

# %%
np.mean(BaseDatos['Unit Cost'])
# Out:
# 187.49414399999978

# %%
data_cost=BaseDatos[['Country','Unit Cost','Total Cost']]
data_panama=data_cost[data_cost.Country=='Panama']

# %%
data_panama['Unit Cost'].isnull().sum()
# Out:
# 0

# %%
cor=BaseDatos.corr()
cor
# Out:
#                Order ID  Units Sold  ...  Total Cost  Total Profit
# Order ID       1.000000    0.017155  ...   -0.003199     -0.001478
# Units Sold     0.017155    1.000000  ...    0.461014      0.586416
# Unit Price    -0.015173   -0.017492  ...    0.749661      0.579024
# Unit Cost     -0.014311   -0.019712  ...    0.758100      0.505936
# Total Revenue -0.002879    0.511821  ...    0.987827      0.883990
# Total Cost    -0.003199    0.461014  ...    1.000000      0.800506
# Total Profit  -0.001478    0.586416  ...    0.800506      1.000000
#
# [7 rows x 7 columns]

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data=cor, annot=True)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data=cor, annot=True,cmap=plt.cm.Blues_r)
plt.show()
plt.figure(figsize=(12,10))
sns.heatmap(data=cor, annot=True,cmap=plt.cm.Blues)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data=cor, annot=True,cmap=plt.cm.Reds)
plt.show()

# %%
# Linear Regression
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score , classification_report
from sklearn.model_selection import train_test_split

# %%
data_cost_x=BaseDatos[['Unit Cost','Total Cost']]
data_total_revenue=BaseDatos[['Total Revenue']]
x_train, x_test,y_train, y_test= train_test_split(data_cost_x, data_total_revenue,test_size=0.3, random_state = 101 )

# %%
def percentage_error(actual, predicted):
    res = np.empty(actual.shape)
    for j in range(actual.shape[0]):
        if actual[j] != 0:
            res[j] = (actual[j] - predicted[j]) / actual[j]
        else:
            res[j] = predicted[j] / np.mean(actual)
    return res

def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs(percentage_error(np.asarray(y_true), np.asarray(y_pred)))) * 100

# %%
lin_regr=linear_model.LinearRegression()

lin_regr.fit(x_train,y_train)

# Coefficients
print('Coefficients: \n',lin_regr.coef_)
# Este es el valor donde corta el eje Y (en X=0)

print('Independent term: \n', lin_regr.intercept_)

total_revenue_prediction=lin_regr.predict(x_test)

# The mean squared error

print('Mean squared error: %.2f'% mean_squared_error(y_test, total_revenue_prediction))

# The coefficient of determination: 1 is perfect prediction

print('Coefficient of determination: %.4f' % r2_score(y_test, total_revenue_prediction))

print('Mean absolute percentage error (MAPE): %.4f' % mean_absolute_percentage_error(y_test, total_revenue_prediction),"%")
# Out:
# Coefficients:
#  [[-507.85391824    1.32557792]]
# Independent term:
#  [185126.66993853]
# Mean squared error: 45770297932.00
# Coefficient of determination: 0.9798
# Mean absolute percentage error (MAPE): 170.0993 %

# %%
df = pd.DataFrame(data_total_revenue,columns=['Total Revenue'])

# mean = np.mean(data['Total Revenue'])

mean = np.mean(total_revenue_prediction)

df.loc[df['Total Revenue'] <= mean, 'equal_or_lower_than_mean'] = 0

df.loc[df['Total Revenue'] > mean, 'equal_or_lower_than_mean'] = 1 

print(mean)

print(df)
# Out:
# 1376969.5832291117
#       Total Revenue  equal_or_lower_than_mean
# 0         140914.56                       0.0
# 1         330640.86                       0.0
# 2         226716.10                       0.0
# 3        1854591.20                       1.0
# 4        1150758.36                       0.0
# ...             ...                       ...
# 4995     3545172.35                       1.0
# 4996      117694.56                       0.0
# 4997     1328477.12                       0.0
# 4998     1028324.80                       0.0
# 4999      377447.00                       0.0
#
# [5000 rows x 2 columns]

# %%
all_x = data_cost_x

all_y = df.equal_or_lower_than_mean

x_train,x_test,y_train,y_test = train_test_split(all_x, all_y, test_size=0.3, random_state = 101)

log_regr = linear_model.LogisticRegression(solver='lbfgs',max_iter=50)

log_regr.fit(x_train,y_train)

pred = log_regr.predict(x_test)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.51      0.64       980
#          1.0       0.48      0.86      0.62       520
#
#     accuracy                           0.63      1500
#    macro avg       0.68      0.69      0.63      1500
# weighted avg       0.74      0.63      0.64      1500

# %%
mean_absolute_percentage_error(y_test,pred)
# Out:
# 97.23333333333333

# %%
# Import data analysis modules import  nump... de Yavar Jarrah Nezhad

# Import data analysis modules

import numpy as np

import pandas as pd

# Import visualization modules

import matplotlib.pyplot as plt

import seaborn as sns

# %matplotlib inline



# Use pandas to read in csv file

train = pd.read_csv('train.csv')

train.head()

#train
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
missing_values=train.isnull()
missing_values.sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(data=missing_values,yticklabels=False, cbar=False,cmap='viridis')

# %%
# Use the countplot() method to identify ratio of who survived vs. not

# (Tip) very helpful to get a visualization of the target label

# x -> argument referes to column of interest

# data -> argument refers to dataset
sns.countplot(x='Survived', data=train)

# %%
# Use the countplot() method to identify ratio of who survived vs. not with interest in Passenger class

# x -> argument referes to column of interest

# data -> argument refers to dataset

# hue -> allows another level to subdivide data

# palette -> argument refers to plot color

sns.countplot(x='Survived', data=train, hue='Pclass')

# %%
import matplotlib.pyplot as plt

#identify outlier with .boxplot() method

plt.figure(figsize=(10,7))

sns.boxplot(x='Pclass',y='Age',data=train)

# %%
# Create function to impute the age value if it is null

def impute_age(cols):
    Age = cols[0]
    Pclass = cols[1]  

    if pd.isnull(Age):      

        if Pclass == 1:

            return 37

        elif Pclass == 2:

            return 29

        else:

            return 24

    else:

        return Age

# Apply function to impute the age for missing values

# The age column is at position 0

# The pclass column is at position 1

# axis -> argument refers to columns instead of rows to apply the impute_age function

train['Age'] = train[['Age', 'Pclass']].apply(impute_age, axis=1)



# create heatmap to dispaly updated age values

# yticklabels -> argument removes the column label

# cbar -> argument removes the color bar

# cmap -> argument defines the color of the map

sns.heatmap(train.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
# use the .drop() to remove columns that have too much missing data
# axis -> refers to either row(0) or column(1) to specify
# inplace -> permanentely removes column instead of just removing the view
train.drop('Cabin',axis=1,inplace=True)
train.head()
# Out:
#    PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0            1         0       3  ...         A/5 21171   7.2500         S
# 1            2         1       1  ...          PC 17599  71.2833         C
# 2            3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3            4         1       1  ...            113803  53.1000         S
# 4            5         0       3  ...            373450   8.0500         S
#
# [5 rows x 11 columns]

# %%
# use .dropna() to remove rows that contain missing data
train.dropna(inplace=True)

# %%
# Use the .get_dummies() method to convert categorical data into dummy values
# train['Sex'] refers to the column we want to convert
# drop_first -> argument avoids the multicollinearity problem, which can undermines
# the statistical significance of an independent variable.

sex = pd.get_dummies(train['Sex'], drop_first=True)
embark = pd.get_dummies(train['Embarked'], drop_first=True)

# Use  .concat() method to merge the series data into one dataframe
train = pd.concat([train, sex, embark], axis=1)

# %%
# Drop columns with categorical data
train.drop(['Sex','Embarked','Ticket','Name','PassengerId'], axis=1, inplace=True)
train
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0           0       3  22.0      1      0   7.2500     1  0  1
# 1           1       1  38.0      1      0  71.2833     0  0  0
# 2           1       3  26.0      0      0   7.9250     0  0  1
# 3           1       1  35.0      1      0  53.1000     0  0  1
# 4           0       3  35.0      0      0   8.0500     1  0  1
# ..        ...     ...   ...    ...    ...      ...   ... .. ..
# 886         0       2  27.0      0      0  13.0000     1  0  1
# 887         1       1  19.0      0      0  30.0000     0  0  1
# 888         0       3  24.0      1      2  23.4500     0  0  1
# 889         1       1  26.0      0      0  30.0000     1  0  0
# 890         0       3  32.0      0      0   7.7500     1  1  0
#
# [889 rows x 9 columns]

# %%
# Split data into 'X' features and 'y' target label sets
X = train[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'male', 'Q', 'S']]
y = train['Survived']

# %%
# Import module to split dataset
from sklearn.model_selection import train_test_split# Split data set into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
# Import module for fitting

from sklearn.linear_model import LogisticRegression# Create instance (i.e. object) of LogisticRegression

#logmodel = LogisticRegression()# Fit the model using the training data
# create and configure model
# logmodel = LogisticRegression(solver='liblinear') # To maintain the old behavior
# logmodel = LogisticRegression(solver='lbfgs') # To support the new behavior

logmodel = LogisticRegression(solver='lbfgs', max_iter=1000) # To support the new behavior

# X_train -> parameter supplies the data features
# y_train -> parameter supplies the target labels

logmodel.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print('Coeficientes:',logmodel.coef_, '\nIntercepto',logmodel.intercept_)
# Out:
# Coeficientes: [[-1.09718690e+00 -4.13194082e-02 -2.46644846e-01 -8.80354449e-02
#    1.63980661e-03 -2.47770742e+00 -1.19120632e-01 -3.26906677e-01]]
# Intercepto [5.00865866]

# %%
predictions = logmodel.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.92      0.87       163
#            1       0.85      0.69      0.76       104
#
#     accuracy                           0.83       267
#    macro avg       0.84      0.81      0.82       267
# weighted avg       0.83      0.83      0.83       267

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

a=b=np.arange(-1,1,0.02)
a,b=np.meshgrid(a,b)
fig=plt.figure(figsize=(8,8))
axes=fig.gca(projection='3d')
axes.plot_surface(a,b,a**2+b**2)
plt.show()

# %%
a=np.arange(-1,1,0.02)
b=np.arange(-2,2,0.02)
a,b=np.meshgrid(a,b)
fig=plt.figure(figsize=(8,8))
axes=fig.gca(projection='3d')
z=a**2+b**2
axes.plot_surface(a,b,z)
plt.show()

# %%
len(z)
# Out:
# 200

# %%
np.argmin(z)
# Out:
# 10050

# %%
np.arange(-1,1,0.02)[50]
# Out:
# 8.881784197001252e-16

# %%
np.arange(-2,2,0.02)[100]
# Out:
# 1.7763568394002505e-15

# %%
z[100,50]
# Out:
# 3.944304526105059e-30

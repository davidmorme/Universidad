# %% [markdown]
# ### **Examen Deep Learning - Primer corte**
#
# Hola chicos y chicas. Aquí haremos el examen. Se responde todo en este notebook.
# Lee detenidamente, cada pregunta tiene su respectiva puntuación.
#
# No añadas ninguna celda más.
#
# ¡Ánimo!  :)

# %%
Nombre = ""#@param{type:"string"}
Codigo = ""#@param{type:"string"}

print("Mi nombre es", Nombre, "y mi código es", Codigo)
# Out:
# Mi nombre es  y mi código es

# %% [markdown]
# (1) **[0.5]** Verdadero o falso: Las redes neuronales pueden aprender gracias a que el algoritmo de optimización Gradient Descent ayuda a la función de coste a llegar a un mínimo global. *Justifica tu respuesta.*

# %%
respuesta = False #@param {type:"boolean"}
justificacion = ""#@param{type:"string"}
print("Respuesta:", respuesta, "porque", justificacion)
# Out:
# Respuesta: False porque

# %% [markdown]
# (2) **[0.5]** Responde: ¿Por qué se realiza la división del dataset en split de train y split de test?

# %%
respuesta = ""#@param{type:"string"}
print("Se realiza porque", respuesta)
# Out:
# Se realiza porque

# %% [markdown]
# (3) **[0.5]** Completa el argumento:
# En un ejercicio de clasificación supervisado, la **última capa** de la red neuronal debe tener la función de activación Softmax porque: ________________________

# %%
respuesta = "" #@param {type:"string"}
print("En un ejercicio de clasificación supervisado, la última capa de la red neuronal debe tener la función de activación porque", respuesta)
# Out:
# En un ejercicio de clasificación supervisado, la última capa de la red neuronal debe tener la función de activación porque

# %% [markdown]
# (4) **[0.5]** Responde: De las funciones de activación presentadas en la gráfica, ¿cuál crees que es más eficiente computacionalmente? y ¿por qué?
# ![funciones.png](data:image/png;base64,...)

# %%
respuesta = "" #@param {type:"string"}
print("La función de activación más eficiente computacionalmente es:",respuesta)
# Out:
# La función de activación más eficiente computacionalmente es:

# %% [markdown]
# (5) **[1.0]** Teniendo en cuenta la gráfica de curvas de aprendizaje de esta celda, indica:
# - 1. ¿Qué pasa con el modelo **antes** de la línea punteada?
# - 2. ¿Qué pasa con el modelo **después** de la línea punteada?
# - 3. ¿Qué indica la línea punteada?
# ![GraficaEntrenamiento.png](data:image/png;base64,...)

# %%
#Respuestas
respuesta1 = ""#@param{type:"string"}
respuesta2 = ""#@param{type:"string"}
respuesta3 = ""#@param{type:"string"}

print("1:", respuesta1)
print("2:", respuesta2)
print("3:", respuesta3)
# Out:
# 1:
# 2:
# 3:

# %% [markdown]
# (6) **[1.0]** Ayuda a Don Julio:
#
# En la tienda de Don Julio se quiere implementar una caja registradora inteligente: un sistema de AI que tenga una cámara y que, al pasar el producto por dicha cámara, este sea capaz de reconocerlo y añada su precio a la cuenta automáticamente. Don Julio vende únicamente: pan Bimbo, cerveza Póker, Choclitos, Frutiño, caldo Maggie, arroz Diana, leche Colanta, papas Margarita, salchichas Zenú y Fabuloso.
#
# Teniendo en cuenta que para optimizar el reconocimiento de los productos, la resolución de la cámara se reducirá de manera que cada imagen sea de 20x20 pixeles y a blanco y negro.
#
# Construye una arquitectura de red neuronal que pueda ayudar a Don Julio a cumplir su sueño de tener una registradora inteligente.

# %%
from tensorflow import keras
from tensorflow.keras import layers

#Debes completar los tamaños (o numero de neuronas) de cada capa. Y, si consideras necesario, añadir más capas.
#Las funciones de activación en keras son: "relu", "sigmoid", "tanh", "softmax"

model = keras.models.Sequential()

#Input
model.add(keras.Input(shape=(0), name="Input"))

#Hidden layers
model.add(layers.Dense(0, name="hidden1", activation=""))
#-------

#Output
model.add(layers.Dense(0, name="Output", activation=""))

model.summary()

# %% [markdown]
# (7) **[0.5]** Explica con tus propias palabras y brevemente cómo aprende una red neuronal mencionando los siguientes conceptos: *Gradient Descent, Backpropagation, Cost Function.*

# %%
respuesta = ""#@param{type:"string"}
print("Respuesta:", respuesta)
# Out:
# Respuesta:

# %% [markdown]
# (8) **[0.5]** Calcula el número de parámetros (pesos y bias) que tendría una red con la arquitectura representada en la gráfica de esta celda.![nn.png](data:image/png;base64,...)

# %%
#Puedes apoyarte en esta celda de código

# %%
numParams = 0 #@param {type:"number"}
print("La red tendría", numParams, "parámetros")
# Out:
# La red tendría 0 parámetros

# %% [markdown]
# (9) **[BONUS 0.3]** Responde: Si mis datos no son suficientes o no tienen demasiada variación, puedo usar la técnica de _______.

# %%
respuesta = ""#@param{type:"string"}
print("Si mis datos no son suficientes o no tienen demasiada variación, puedo usar la técnica de", respuesta)
# Out:
# Si mis datos no son suficientes o no tienen demasiada variación, puedo usar la técnica de

# %% [markdown]
# ## ¡Genial! Ya has terminado :)
